# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
df= pd.read_csv('batting_stats.csv')

# %%
df.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
#SIMPLE BAR CHART

# %%
Childern = [40,20,50,10,20]
Colors = ['red','blue','green','yellow','pink']

plt.bar(Colors,Childern,color = 'green')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(Colors,Childern,color='gold')
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.read_csv('batting_stats.csv')

# %%
df.head(2)
# Out:
#      batter  runs        avg  strike_rate
# 0   V Kohli  6634  36.251366   125.977972
# 1  S Dhawan  6244  34.882682   122.840842

# %%
plt.bar(df['batter'],df['runs'])
# Out:
# <BarContainer object of 50 artists>

# %%
children = [10,20,40,10,30]
colors = ['red','blue','green','yellow','pink']
plt.barh(colors,children,color='gold')
plt.show()

# %%
children = [10,20,40,10,30]
colors = ['red red red red red red',
'blue blue blue blue',
'green green green green green',
'yellow yellow yellow yellow ',
'pink pinkpinkpink']
plt.barh(colors,children,color='black')
plt.show()
